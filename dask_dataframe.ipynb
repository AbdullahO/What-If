# %%
from dask.distributed import Client, progress
client = Client(threads_per_worker=4, n_workers=2)
client
# Out:
# 2022-10-15 19:07:34,815 - distributed.diskutils - INFO - Found stale lock file and directory '/Users/michael/whatIf/algorithms/dask-worker-space/worker-6kchfkbs', purging
# 2022-10-15 19:07:34,815 - distributed.diskutils - INFO - Found stale lock file and directory '/Users/michael/whatIf/algorithms/dask-worker-space/worker-5nvucde3', purging
# 2022-10-15 19:07:34,815 - distributed.diskutils - INFO - Found stale lock file and directory '/Users/michael/whatIf/algorithms/dask-worker-space/worker-ot94z5ig', purging
# <Client: 'tcp://127.0.0.1:51374' processes=2 threads=8, memory=32.00 GiB>

# %%
import pandas as pd

pre_df = pd.read_pickle("../data/basque_pre_df.pkl")

# %%
pre_df.head()
# Out:
#                      unit intervention metric      1955      1956      1957  \
# 0          Spain (Espana)      control    gdp  2.354542  2.480149  2.603613
# 1               Andalucia      control    gdp  1.688732  1.758498  1.827621
# 2                  Aragon      control    gdp  2.288775  2.445159  2.603399
# 3  Principado De Asturias      control    gdp  2.502928  2.615538  2.725793
# 4        Baleares (Islas)      control    gdp  3.143959  3.347758  3.549629
#
#        1958      1959      1960      1961      1962      1963      1964  \
# 0  2.637104  2.669880  2.869966  3.047486  3.273279  3.493502  3.600114
# 1  1.852756  1.878035  2.010140  2.129177  2.280348  2.431020  2.508855
# 2  2.639032  2.677092  2.881462  3.099543  3.359183  3.614182  3.680091
# 3  2.751857  2.777421  2.967295  3.143887  3.373536  3.597258  3.672594
# 4  3.642673  3.734862  4.058841  4.360254  4.646173  4.911525  5.050700
#
#        1965      1966      1967      1968      1969      1970
# 0  3.700800  3.823479  3.939660  4.173736  4.410526  4.591688
# 1  2.584690  2.694444  2.802342  2.987361  3.179092  3.354327
# 2  3.745287  3.883319  4.016138  4.243645  4.476221  4.596258
# 3  3.743359  3.909383  4.073122  4.308626  4.549700  4.631605
# 4  5.184662  5.466795  5.737646  6.161454  6.581691  6.887032

# %%
from dask.dataframe import from_pandas
ddf = from_pandas(pre_df, npartitions=3)

# %%
ddf.head()
# Out:
#                      unit intervention metric      1955      1956      1957  \
# 0          Spain (Espana)      control    gdp  2.354542  2.480149  2.603613
# 1               Andalucia      control    gdp  1.688732  1.758498  1.827621
# 2                  Aragon      control    gdp  2.288775  2.445159  2.603399
# 3  Principado De Asturias      control    gdp  2.502928  2.615538  2.725793
# 4        Baleares (Islas)      control    gdp  3.143959  3.347758  3.549629
#
#        1958      1959      1960      1961      1962      1963      1964  \
# 0  2.637104  2.669880  2.869966  3.047486  3.273279  3.493502  3.600114
# 1  1.852756  1.878035  2.010140  2.129177  2.280348  2.431020  2.508855
# 2  2.639032  2.677092  2.881462  3.099543  3.359183  3.614182  3.680091
# 3  2.751857  2.777421  2.967295  3.143887  3.373536  3.597258  3.672594
# 4  3.642673  3.734862  4.058841  4.360254  4.646173  4.911525  5.050700
#
#        1965      1966      1967      1968      1969      1970
# 0  3.700800  3.823479  3.939660  4.173736  4.410526  4.591688
# 1  2.584690  2.694444  2.802342  2.987361  3.179092  3.354327
# 2  3.745287  3.883319  4.016138  4.243645  4.476221  4.596258
# 3  3.743359  3.909383  4.073122  4.308626  4.549700  4.631605
# 4  5.184662  5.466795  5.737646  6.161454  6.581691  6.887032

# %%
from dask_ml.preprocessing import StandardScaler
